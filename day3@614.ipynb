# %%
import pandas as pd

# %%
#To access specific row
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.randn(5, 4), ['A','B','C','D','E'], ['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A -0.902051 -0.077067  1.388499 -1.087517
# B -1.315885 -1.073537 -1.205824  0.181928
# C -0.607700  0.755525 -0.332826 -1.675339
# D  0.463010 -0.351032 -0.977724  0.868415
# E  0.164357  0.676339  0.275558  0.360216

# %%
#Retreveiwing data based on the condition

# %%
#To get access specific values of coordinates in a DataFrame
df.loc['B',2] #syntax--->df.loc[row,col]
# Out:
# -1.4416982103558704

# %%
#To accces multiple rows

# %%
#To get multiple co -ordinates 
df.loc[['A','B'],['W','Z']]
# Out:
#           W         Z
# A -0.902051 -1.087517
# B -1.315885  0.181928

# %%
#Retreveiwing data based on the condition

# %%
#To get the all the values greater than 0
df>0
# Out:
#        W      X      Y      Z
# A  False  False   True  False
# B  False  False  False   True
# C  False   True  False  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN       NaN  1.388499       NaN
# B       NaN       NaN       NaN  0.181928
# C       NaN  0.755525       NaN       NaN
# D  0.463010       NaN       NaN  0.868415
# E  0.164357  0.676339  0.275558  0.360216

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# D  0.463010 -0.351032 -0.977724  0.868415
# E  0.164357  0.676339  0.275558  0.360216

# %%
# To get access multiple rows
df.loc[['A','C']]
# Out:
#           W         X         Y         Z
# A -0.902051 -0.077067  1.388499 -1.087517
# C -0.607700  0.755525 -0.332826 -1.675339

# %%
#How to handle missing data 
df
# Out:
#           W         X         Y         Z
# A -0.902051 -0.077067  1.388499 -1.087517
# B -1.315885 -1.073537 -1.205824  0.181928
# C -0.607700  0.755525 -0.332826 -1.675339
# D  0.463010 -0.351032 -0.977724  0.868415
# E  0.164357  0.676339  0.275558  0.360216

# %%
d={"A":[1,2,np.nan],"B":[5,np.nan,np.nan],"C":[1,2,3],"D":[np.nan,np.nan,np.nan]}

# %%
df1=pd.DataFrame(d)
df1
# Out:
#      A    B  C   D
# 0  1.0  5.0  1 NaN
# 1  2.0  NaN  2 NaN
# 2  NaN  NaN  3 NaN

# %%
df['W']
# Out:
# A   -0.902051
# B   -1.315885
# C   -0.607700
# D    0.463010
# E    0.164357
# Name: W, dtype: float64

# %%
#to drop the values with Nan
#dropna()
df1.dropna()  #The rows which has na is deleted
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
#dropna(how,thresh,axis,inplace)
#how="all" or "any"
df1.dropna(how="all")   #all means it'll checking the rows with all nan values to delete that row
# Out:
#      A    B  C   D
# 0  1.0  5.0  1 NaN
# 1  2.0  NaN  2 NaN
# 2  NaN  NaN  3 NaN

# %%
df1.dropna(how="any")  #any means -->it'll delete the rows which have any single nan value
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df1.dropna(how='all',axis=1)  #checking based on the coloumns
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df1.dropna(how='any',axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
#to check the sum of  nan values in each row 
#dropna is usedto del all rows and coloumns
df1.isna
# Out:
# <bound method DataFrame.isna of      A    B  C   D
# 0  1.0  5.0  1 NaN
# 1  2.0  NaN  2 NaN
# 2  NaN  NaN  3 NaN>

# %%
#to find the sum 
df1.isna().sum()
# Out:
# A    1
# B    2
# C    0
# D    3
# dtype: int64

# %%
#Thresh ---> Breaking point(
df1.dropna(thresh=2)
# Out:
#      A    B  C   D
# 0  1.0  5.0  1 NaN
# 1  2.0  NaN  2 NaN

# %%
df1.dropna(thresh=1)
# Out:
#      A    B  C   D
# 0  1.0  5.0  1 NaN
# 1  2.0  NaN  2 NaN
# 2  NaN  NaN  3 NaN

# %%
df1.dropna(thresh=2,axis=1)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3

# %%
#fillna() --->Handling all the null values 
df1.fillna(value=0.0)  #it stores all the nan values as 0.0
# Out:
#      A    B  C    D
# 0  1.0  5.0  1  0.0
# 1  2.0  0.0  2  0.0
# 2  0.0  0.0  3  0.0

# %%
df1.fillna(value=0)
# Out:
#      A    B  C    D
# 0  1.0  5.0  1  0.0
# 1  2.0  0.0  2  0.0
# 2  0.0  0.0  3  0.0

# %%
df1['A'].fillna(value=df1['A'].mean())   #to find the mean of the particular coloumn
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
#Grop by
#How to group based on coloumn and perform  aggregate functions
data={'company':['Google','Google','Meta','Meta','Fb','Fb'],'Person':['sani','nani','sai','prasanth','mohan','mounika'],'Sales':[300,500,100,200,600,20]}
df2=pd.DataFrame(data)

# %%
df2
# Out:
#   company    Person  Sales
# 0  Google      sani    300
# 1  Google      nani    500
# 2    Meta       sai    100
# 3    Meta  prasanth    200
# 4      Fb     mohan    600
# 5      Fb   mounika     20

# %%
#bycompany
bycomp=df2.groupby('company')

# %%
bycomp

# %%
bycomp.sum()
# Out:
#                Person  Sales
# company
# Fb       mohanmounika    620
# Google       saninani    800
# Meta      saiprasanth    300

# %%
bycomp['Person']

# %%
bycomp.describe()
# Out:
#         Sales
#         count   mean         std    min    25%    50%    75%    max
# company
# Fb        2.0  310.0  410.121933   20.0  165.0  310.0  455.0  600.0
# Google    2.0  400.0  141.421356  300.0  350.0  400.0  450.0  500.0
# Meta      2.0  150.0   70.710678  100.0  125.0  150.0  175.0  200.0

# %%
df2['company'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0    Google
# 1    Google
# 2      Meta
# 3      Meta
# 4        Fb
# 5        Fb
# Name: company, dtype: object>

# %%
bycomp[['Person','Sales']].max()
#bycomp.describe()
#df2
# Out:
#           Person  Sales
# company
# Fb       mounika    600
# Google      sani    500
# Meta         sai    200

# %%
#How to access CSV_file using 
df=pd.read_csv(r"C:\Users\micro\Downloads\samplecsv.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# to get fisrst five rows
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 37075  Food product manufacturing  Percentage           H37
# 37076  Food product manufacturing  Percentage           H38
# 37077  Food product manufacturing  Percentage           H39
# 37078  Food product manufacturing  Percentage           H40
# 37079  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 37075                          Quick ratio  Financial ratios    52
# 37076  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
#to get first five rows
df.head(10)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
# 5  2020                     Level 1                99999       All industries
# 6  2020                     Level 1                99999       All industries
# 7  2020                     Level 1                99999       All industries
# 8  2020                     Level 1                99999       All industries
# 9  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# ...

# %%
#header-->is used to mention the coloumn names of the data frame
df=pd.read_csv(r"C:\Users\micro\Downloads\samplecsv.csv",header=4)

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\micro\Downloads\delimatercsv.csv",sep=';',names=['sid','ages','places'])
df
# Out:
#        sid ages         places
# 0     Name  Age           City
# 1    Alice   25       New York
# 2      Bob   30  San Francisco
# 3  Charlie   22    Los Angeles

# %%
df=pd.read_csv(r"C:\Users\micro\Downloads\delimatercsv.csv",sep=';')
names={"Name":'sid',"Age":'all_ages',"Place":'Chennai'}
df=df.rename(columns=names)
df
# Out:
#        sid  all_ages           City
# 0    Alice        25       New York
# 1      Bob        30  San Francisco
# 2  Charlie        22    Los Angeles

# %%
df_titanic=pd.read_csv(r"C:\Users\micro\Downloads\titanic_train.csv")

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df_titanic['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_titanic.fillna(value=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.isnull().sum() #isnull is used to find how many null values are presentin it
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
df_titanic.isna().sum()/df_titanic.shape[0]*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df_titanic=pd.read_csv(r"C:\Users\micro\Downloads\titanic_train.csv")

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Find how many are dead?

# %%
#matplotib
#-->It is data vizualization library,which was inspired by matlab
#It is used for data vizualization in the form of various plots

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[5,6,7,8]
plt.figure(figsize=(3,3))
plt.plot(x,y)

# %%
plt.subplot(1,2,1) #subplot(num_of_
plt.plot(x,y)

# %%
plt.subplot(1,2,2) #subplot(num_of_row,num_ofcol,plot_number)
plt.plot(y,x,'r')
plt.figure(figsize=(2,2))
plt.subplot(1,2,1)
plt.plot(x,y,'g')

# %%
plt.figure(figsize=(2,2))
plt.subplot(1,2,1)    #subplot(num_of_row,num_ofcol,plot_number)
plt.plot(x,y,'g')

# %%
plt.figure(figsize=(3,1))
plt.subplot(2,1,2)  #subplot(num_of_row,num_ofcol,plot_number)
plt.plot(x,y,'r')

# %%
import numpy as np
x_years=np.arange(2000,2005,dtype=int)
y_innova=np.array([20,40,10,14,23])
y_honda_city=np.array([10,5,12,40, 25])
x_years,y_innova
# Out:
# (array([2000, 2001, 2002, 2003, 2004]), array([20, 40, 10, 14, 23]))

# %%
plt.figure(figsize=(4,4))
plt.plot(x_years,y_innova, '--g')
plt.plot(x_years,y_honda_city, '--y')
plt.xlabel("Years")
plt.ylabel("No of cars")
plt.title("Car Statistics")
plt.legend(["Innova","City"])

# %%
#barplot
products=['Tv','Laptop','Smart phone','sid shoes','shirt']
sales=np.random.randint(30,200,size=len(products))
plt.bar(products,sales,color='green')
# Out:
# <BarContainer object of 5 artists>

# %%
products=['Tv','Laptop','Smart phone','sid shoes','shirt']
sales=np.random.randint(30,200,size=len(products))
plt.bar(products,sales,color=["green","red","orange","pink","yellow"], width=0.3,edgecolor="black")
# Out:
# <BarContainer object of 5 artists>

# %%
products=['Tv','Laptop','Smart phone','sid shoes','shirt']
sales=np.random.randint(30,200,size=len(products))
plt.barh(products,sales,color=["green","red","orange","pink","yellow"],height=0.3,edgecolor="black")
# Out:
# <BarContainer object of 5 artists>

# %%
products=['Tv','Laptop','Smart phone','sid shoes','shirt']
sales=np.random.randint(30,200,size=len(products))
plt.bar(products,sales,color=["green","red","orange","pink","yellow"], width=0.3,edgecolor="black",label="Car statistics")
plt.xlabel("Price")
plt.ylabel("Products")
# Out:
# Text(0, 0.5, 'Products')

# %%
student_name=["Lali","sita","Ram","likki"]
scores=[20,44,30,78]
plt.figure(figsize=(3,4))
plt.pie(scores,labels=student_name)
# Out:
# ([<matplotlib.patches.Wedge at 0x2450b9b02c0>,
# ...
#  [Text(1.02741771554168, 0.3929539894073042, 'Lali'),
#   Text(0.04017419305110476, 1.099266134388162, 'sita'),
#   Text(-1.0642320719124805, 0.2782267009344519, 'Ram'),
#   Text(0.16016130938908807, -1.0882777012209581, 'likki')])

# %%
df_titanic["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
male=(df_titanic['Sex']=='male').sum()
female=(df_titanic['Sex']=='female').sum()
counts=['male','female']
names=["male","female"]
plt.bar(names,counts,width=0.3)
# Out:
# <BarContainer object of 2 artists>

# %%
#Scatterplot,hist plot,box plot

# %%
# 1.)Draw box plot based on the pclaps on titanic dataset
#2.)Rename the Sex feild in titanic dataset to "Gender"
#3.)Convert the male to 0 and  female to 1in titanic dataset
#4.)Select the data who are age less than 25 and gender is 1
#5.)check how many male have survived and female have survived.
#6.)plot a graph to show the count of survoires and non-survoiers
#7.)For each embarked port

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
